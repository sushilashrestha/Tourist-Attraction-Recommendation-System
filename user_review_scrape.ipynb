# %%
import pandas as pd

# %%
df = pd.read_csv("Dataset/Attractions.csv")

# %%
df.head()
# Out:
#    ID                      Name           Category       City  Country  \
# 0   1   Bhaktapur Durbar Square    Historical Site  Bhaktapur    Nepal
# 1   2            Changu Narayan             Temple    Unknown    Nepal
# 2   3          Nyatapola Temple             Temple  Bhaktapur    Nepal
# 3   4           Taumadhi Square  Commercial Street    Unknown  Unknown
# 4   5  Doleshwar Mahadev Temple             Temple    Unknown  Unknown
#
#         Latitude      Longitude    Description Entry_Time Fee   Visit_Time
# 0      27.672078     85.4281306  Not Available          0   0    2-3 hours
# 1     27.7164115     85.4279333  Not Available          0   0      1-2 hrs
# 2     27.6714097     85.4293725  Not Available          0   0  1 - 2 hours
# 3  Not Available  Not Available  Not Available          0   0    2-3 hours
# 4  Not Available  Not Available  Not Available          0   0    Not Found

# %%
nepal = df[df['Country'] == 'Nepal'].reset_index()
nepal.head()
# Out:
#    index  ID                     Name         Category       City Country  \
# 0      0   1  Bhaktapur Durbar Square  Historical Site  Bhaktapur   Nepal
# 1      1   2           Changu Narayan           Temple    Unknown   Nepal
# 2      2   3         Nyatapola Temple           Temple  Bhaktapur   Nepal
# 3      5   6           Siddha Pokhari  Historical Site  Bhaktapur   Nepal
# 4      6   7                    Thimi             Town    Unknown   Nepal
#
#      Latitude   Longitude    Description Entry_Time Fee   Visit_Time
# 0   27.672078  85.4281306  Not Available          0   0    2-3 hours
# 1  27.7164115  85.4279333  Not Available          0   0      1-2 hrs
# 2  27.6714097  85.4293725  Not Available          0   0  1 - 2 hours
# 3  27.6720253  85.4204415  Not Available          0   0      1-2 hrs
# 4  27.6732593  85.3864013  Not Available          0   0     1-2 days

# %%
places = nepal["Name"].tolist()

places
# Out:
# ['Bhaktapur Durbar Square',
#  'Changu Narayan',
#  'Nyatapola Temple',
#  'Siddha Pokhari',
#  'Thimi',
#  'Bhairavnath Temple, Bhaktapur',
#  'The Lion Gate, Bhaktapur',
#  'Taleju Temple',
#  'Shree Vishwokarma Agam Chhen',
#  'Aadipadma Mahavihar',
#  'Lokeshwor temple of Bhaktapur',
#  'Indra Varna Mahavihar (Inabaha)',
#  'Mangal Dharmadweep Mahavihar (Jhaur Bahi)',
#  'Dipankar Mahavihar',
#  'Jayakriti Mahavihar (Thathu Bahi)',
#  'Chuma Ganesha Temple',
#  'Salan Ganesh Dyo Chhen',
#  'Aesamari Sattal of Taumadhi Square',
#  'Jetha Ganesh Temple',
#  'Uma Maheshwor temple',
#  'Bhajyapukhu of Bhaktapur',
#  'Tripurasundari Dhungedhara (the stone conduit of Tripurasundari)',
#  'Jagannath temple of Tulachhen',
#  'The image of Chatur Narayan',
#  'Digu Bhairava Temple',
#  'Bakhachhen Mahadev Temple and Siwa Ganesh temple',
#  'Gunakriti Mahavihar',
#  'Vishnu Kunda (Sungaa Pukhu)',
#  'Shree 3 Vishnu Bir mai Temple (Sungaa Dyo)',
#  'Thimi Layaku',
# ...

# %%
nepal.to_csv("nepal.csv")
